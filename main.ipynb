# %% [markdown]
# # Setting up everything

# %%
# !python -m mani_skill.utils.download_demo "StackCube-v1" -o "demos"
# !python -m mani_skill.utils.download_demo "PickCube-v1" -o "demos"

# %%
# !python -W ignore -m mani_skill.trajectory.replay_trajectory \
    --traj-path demos/PickCube-v1/teleop/trajectory.h5 --save-traj \
    --obs-mode state -c "pd_joint_delta_pos" --num-procs 4 --record-rewards True --save-video

# !python -W ignore -m mani_skill.trajectory.replay_trajectory \
    --traj-path demos/StackCube-v1/teleop/trajectory.h5 --save-traj \
    --obs-mode state -c "pd_joint_delta_pos" --num-procs 1 --record-rewards True --save-video

# %%
ENV_NAME = "PickCube-v1"
# %load_ext tensorboard

# %% [markdown]
# # Intial test with variying parameters

# %%
# !python -W ignore ./scripts/sac.py  --exp_name low_256_4e-4 --batch_size 256 --q_lr 4e-4 --policy_lr 3e-4 --buffer_size 1e6

# %%
# !python -W ignore ./scripts/sac.py  --exp_name low_512_4e-4 --batch_size 512 --q_lr 4e-4 --policy_lr 3e-4 --buffer_size 1e6

# %%
# !python -W ignore ./scripts/sac.py  --exp_name low_768_4e-4 --batch_size 768 --q_lr 4e-4 --policy_lr 3e-4 --buffer_size 1e6

# %%
# !python -W ignore ./scripts/sac.py  --exp_name low_256_6e-4 --batch_size 256 --q_lr 6e-4 --policy_lr 3e-4 --buffer_size 1e6

# %%
# !python -W ignore ./scripts/sac.py  --exp_name low_512_6e-4 --batch_size 512 --q_lr 6e-4 --policy_lr 3e-4 --buffer_size 1e6

# %%
# !python -W ignore ./scripts/sac.py  --exp_name low_768_6e-4 --batch_size 768 --q_lr 6e-4 --policy_lr 3e-4 --buffer_size 1e6

# %%
# !python -W ignore ./scripts/sac.py  --exp_name low_1024_6e_4 --batch_size 1024 --q_lr 6e-4 --policy_lr 3e-4 --buffer_size 1e6

# %%
# !python -W ignore ./scripts/sac.py  --exp_name low_2048_6e_4 --batch_size 2048 --q_lr 6e-4 --policy_lr 3e-4 --buffer_size 1e6

# %%
# !python -W ignore ./scripts/sac.py  --exp_name low_256_4e_4_double --batch_size 256 --q_lr 4e-4 --policy_lr 3e-4 --buffer_size 2e6

# %%
# !python -W ignore ./scripts/sac.py  --exp_name low_512_4e_4_double --batch_size 512 --q_lr 4e-4 --policy_lr 3e-4 --buffer_size 2e6

# %%
# !python -W ignore ./scripts/sac.py  --exp_name low_768_4e_4_double --batch_size 768 --q_lr 4e-4 --policy_lr 3e-4 --buffer_size 2e6

# %%
# !python -W ignore ./scripts/sac.py  --exp_name low_768_1e-3 --batch_size 768 --q_lr 1e-3 --policy_lr 3e-4 --buffer_size 1e6

# %% [markdown]
# # With the inclusion of the demo data

# %%
# !python -W ignore ./scripts/sac.py  --exp_name demo_05 --use_demo --demo_percent 0.05

# %%
# !python -W ignore ./scripts/sac.py  --exp_name demo_10 --use_demo --demo_percent 0.1

# %%
# !python -W ignore ./scripts/sac.py  --exp_name demo_20 --use_demo --demo_percent 0.2

# %%
# !python -W ignore ./scripts/sac.py  --exp_name demo_30 --use_demo --demo_percent 0.3

# %%
# !python -W ignore ./scripts/sac.py  --exp_name demo_40 --use_demo --demo_percent 0.4

# %%
# !python -W ignore ./scripts/sac.py  --exp_name demo_50--use_demo --demo_percent 0.5

# %% [markdown]
# # Prioritized Experience Replay

# %% [markdown]
# ## Max vs Using mean and std

# %%
# !python -W ignore ./scripts/sac_per.py  --exp_name per_with_max  --per_alpha 0.4 --per_beta_start 0.4 --per_beta_frames 25000 --learning_starts 5 --use_max_priority

# %%
# !python -W ignore ./scripts/sac_per.py  --exp_name per_with_mean  --per_alpha 0.4 --per_beta_start 0.4 --per_beta_frames 25000 --learning_starts 5

# %% [markdown]
# ## Varing the parameters

# %%
# !python -W ignore ./scripts/sac_per.py  --exp_name per_a0_2_b0_4_bf25000  --per_alpha 0.2 --per_beta_start 0.4 --per_beta_frames 25000 --learning_starts 5

# %%
# !python -W ignore ./scripts/sac_per.py  --exp_name per_a0_4_b0_4_bf25000  --per_alpha 0.4 --per_beta_start 0.4 --per_beta_frames 25000 --learning_starts 5

# %%
# !python -W ignore ./scripts/sac_per.py  --exp_name per_a0_6_b0_4_bf25000  --per_alpha 0.6 --per_beta_start 0.4 --per_beta_frames 25000 --learning_starts 5

# %%
# !python -W ignore ./scripts/sac_per.py  --exp_name per_a0_4_b0_6_bf25000  --per_alpha 0.4 --per_beta_start 0.6 --per_beta_frames 25000 --learning_starts 5

# %%
# !python -W ignore ./scripts/sac_per.py  --exp_name per_a0_4_b0_2_bf25000  --per_alpha 0.4 --per_beta_start 0.2 --per_beta_frames 25000 --learning_starts 5

# %%
# !python -W ignore ./scripts/sac_per.py  --exp_name per_a0_4_b0_4_bf50000  --per_alpha 0.4 --per_beta_start 0.4 --per_beta_frames 50000 --learning_starts 5

# %%
# !python -W ignore ./scripts/sac_per.py  --exp_name per_a0_4_b0_4_bf10000  --per_alpha 0.4 --per_beta_start 0.4 --per_beta_frames 10000 --learning_starts 5

# %% [markdown]
# ## Final best of all

# %%
# !python -W ignore ./scripts/sac.py  --exp_name "Batchsize_2048__Q_lr_2e-3__Policy_lr_6e-4" --batch_size 2048 --q_lr 2e-3 --policy_lr 6e-4 --buffer_size 1e6 --num_envs 512 --total_timesteps 100000

# %%
# !python -W ignore ./scripts/sac.py  --exp_name "Demo_05_Batchsize_2048__Q_lr_2e-3__Policy_lr_6e-4" --batch_size 2048 --q_lr 2e-3 --policy_lr 6e-4 --buffer_size 1e6 --num_envs 512 --total_timesteps 100000 --use_demo --demo_percent 0.05

# %%
# !python -W ignore ./scripts/sac_per.py  --exp_name "PER__alpha_0_4__beta_0_4__Beta_frames_25000"  --batch_size 2048 --q_lr 2e-3 --policy_lr 6e-4 --buffer_size 1e6 --num_envs 512 --per_alpha 0.4 --per_beta_start 0.4 --per_beta_frames 25000

# %% [markdown]
# # Final best of all (Reward Rescaled)

# %%
# !python -W ignore ./scripts/sac.py  --exp_name "R_Batchsize_2048__Q_lr_2e-3__Policy_lr_6e-4" --batch_size 2048 --q_lr 2e-3 --policy_lr 6e-4 --buffer_size 1e6 --num_envs 512  --RESCALE_REWARDS

# %%
# !python -W ignore ./scripts/sac.py  --exp_name "R_Demo_05_Batchsize_2048__Q_lr_2e-3__Policy_lr_6e-4" --batch_size 2048 --q_lr 2e-3 --policy_lr 6e-4 --buffer_size 1e6 --num_envs 512 --use_demo --demo_percent 0.05 --RESCALE_REWARDS --learning_starts 5

# %%
# !python -W ignore ./scripts/sac_per.py  --exp_name "R_PER__alpha_0_4__beta_0_4__Beta_frames_25000"  --batch_size 2048 --q_lr 2e-3 --policy_lr 6e-4 --buffer_size 1e6 --num_envs 512 --per_alpha 0.4 --per_beta_start 0.4 --per_beta_frames 25000 --RESCALE_REWARDS

# %% [markdown]
# # Evaluation and generating video
#
# Change the file name in the checkpoint to generate the video. The generated video will be present in the same folder as the checkpoint.

# %%
# !python -W ignore ./scripts/sac.py --evaluate --num_eval_envs 8 --capture-video --total_timesteps 800 --checkpoint "runs/reward_sucess_bench/PickCube-v1__R_PER__alpha_0_4__beta_0_4__Beta_frames_25000__1__1716273580/model_48000.pt"
# Out:
# Evaluation mode is activated, will not track the experiment
# MESA-INTEL: warning: Performance support disabled, consider sysctl dev.i915.perf_stream_paranoid=0
#
# MESA-INTEL: warning: Performance support disabled, consider sysctl dev.i915.perf_stream_paranoid=0
#
# Saving eval videos to runs/reward_sucess_bench/PickCube-v1__R_PER__alpha_0_4__beta_0_4__Beta_frames_25000__1__1716273580/test_videos
# 2024-05-21 15:28:23,718 - mani_skill  - WARNING - mani_skill is not installed with git.
# Model loaded from runs/reward_sucess_bench/PickCube-v1__R_PER__alpha_0_4__beta_0_4__Beta_frames_25000__1__1716273580/model_48000.pt
# env_step=4096, episodic_return=1.5578813552856445
# success =  tensor([False, False, False,  True, False, False, False, False],
#        device='cuda:0')
# env_step=6656, episodic_return=1.8048739731311798
# success =  tensor([False, False, False, False, False, False,  True, False],
#        device='cuda:0')
# env_step=10240, episodic_return=3.2147869169712067
# success =  tensor([False, False, False, False,  True, False, False, False],
#        device='cuda:0')
# env_step=10752, episodic_return=0.49398550391197205
# success =  tensor([False, False, False, False, False,  True, False, False],
#        device='cuda:0')
# env_step=11264, episodic_return=0.43860840797424316
# success =  tensor([False, False, False, False, False, False, False,  True],
#        device='cuda:0')
# env_step=12288, episodic_return=0.8680131137371063
# success =  tensor([False, False,  True,  True, False, False, False, False],
#        device='cuda:0')
# env_step=13312, episodic_return=0.6480450332164764
# success =  tensor([False,  True, False, False, False, False, False, False],
#        device='cuda:0')
# env_step=14848, episodic_return=1.048602670431137
# success =  tensor([False, False, False, False, False, False,  True, False],
#        device='cuda:0')
# env_step=15872, episodic_return=0.7782036662101746
# success =  tensor([ True, False, False, False, False,  True, False, False],
#        device='cuda:0')
# env_step=16896, episodic_return=0.6006405055522919
# success =  tensor([False, False, False, False, False, False, False,  True],
#        device='cuda:0')
# env_step=18944, episodic_return=1.1620270758867264
# success =  tensor([False, False, False, False,  True, False, False, False],
#        device='cuda:0')
# env_step=20992, episodic_return=1.4368935823440552
# success =  tensor([False,  True, False, False, False, False, False, False],
#        device='cuda:0')
# env_step=24064, episodic_return=2.666943311691284
# success =  tensor([ True, False, False,  True, False, False, False, False],
#        device='cuda:0')
# env_step=24576, episodic_return=0.43199819326400757
# success =  tensor([False, False,  True, False, False, False, False, False],
#        device='cuda:0')
# env_step=25088, episodic_return=0.3799755573272705
# success =  tensor([False, False, False, False,  True, False, False, False],
#        device='cuda:0')
# env_step=25600, episodic_return=0.35428518056869507
# success =  tensor([False, False, False, False, False,  True, False, False],
#        device='cuda:0')
# env_step=27648, episodic_return=1.1956810355186462
# success =  tensor([False, False, False, False, False, False,  True, False],
#        device='cuda:0')
# env_step=30208, episodic_return=1.795557290315628
# success =  tensor([False, False, False, False, False, False, False,  True],
#        device='cuda:0')
# env_step
False, False, False,  True, False, False],
#        device='cuda:0')
# env_step=219648, episodic_return=0.7392900884151459
# success =  tensor([False, False,  True, False, False, False, False, False],
#        device='cuda:0')
# env_step=224256, episodic_return=3.8459795117378235
# success =  tensor([False, False, False,  True, False, False, False, False],
#        device='cuda:0')
# env_step=225792, episodic_return=1.5216310322284698
# success =  tensor([False, False, False, False, False, False, False,  True],
#        device='cuda:0')
# env_step=226304, episodic_return=0.49632877111434937
# success =  tensor([False,  True, False, False, False, False, False, False],
#        device='cuda:0')
# env_step=227328, episodic_return=0.8318198323249817
# success =  tensor([False, False, False, False,  True, False, False, False],
#        device='cuda:0')
# env_step=228864, episodic_return=1.2273277640342712
# success =  tensor([False, False, False, False, False,  True, False, False],
#        device='cuda:0')
# env_step=229888, episodic_return=0.8018291592597961
# success =  tensor([False, False,  True, False, False, False, False, False],
#        device='cuda:0')
# env_step=230400, episodic_return=0.38183337450027466
# success =  tensor([False, False, False,  True, False, False, False, False],
#        device='cuda:0')
# env_step=237056, episodic_return=5.474753141403198
# success =  tensor([False, False, False, False, False,  True, False, False],
#        device='cuda:0')
# env_step=238592, episodic_return=1.3680105209350586
# success =  tensor([False,  True, False, False, False, False, False,  True],
#        device='cuda:0')
# env_step=239104, episodic_return=0.3611920475959778
# success =  tensor([False, False, False, False,  True, False, False, False],
#        device='cuda:0')
# env_step=242688, episodic_return=2.541886121034622
# success =  tensor([False, False, False, False, False, False, False, False],
#        device='cuda:0')
# env_step=243200, episodic_return=0.46897372603416443
# success =  tensor([False, False, False, False, False, False,  True, False],
#        device='cuda:0')
# env_step=245248, episodic_return=1.6858763098716736
# success =  tensor([False, False,  True, False, False, False, False, False],
#        device='cuda:0')
# env_step=245760, episodic_return=0.4337240755558014
# success =  tensor([False, False, False,  True, False, False, False, False],
#        device='cuda:0')
# env_step=246272, episodic_return=0.38212692737579346
# success =  tensor([False,  True, False, False, False, False, False, False],
#        device='cuda:0')
# env_step=246784, episodic_return=0.3312082290649414
# success =  tensor([False, False, False, False, False,  True, False, False],
#        device='cuda:0')
# env_step=247808, episodic_return=0.5859409868717194
# success =  tensor([False, False, False, False,  True, False, False, False],
#        device='cuda:0')
# env_step=251392, episodic_return=2.556476354598999
# success =  tensor([False, False, False,  True, False, False, False, False],
#        device='cuda:0')
# env_step=252928, episodic_return=1.495091289281845
# success =  tensor([ True, False, False, False, False, False, False, False],
#        device='cuda:0')
# env_step=253440, episodic_return=0.49269455671310425
# success =  tensor([False, False, False, False, False, False,  True, False],
#        device='cuda:0')
# env_step=253952, episodic_return=0.4349464178085327
# success =  tensor([False, False, False, False, False, False, False,  True],
#        device='cuda:0')
# env_step=256000, episodic_return=1.5785434544086456
# success =  tensor([False,  True, False, False, False, False, False, False],
#        device='cuda:0')
# env_step=256512, episodic_return=0.4506337642669678
# success =  tensor([False, False,  True, False, False,  True, False, False],
#        device='cuda:0')
# env_step=257536, episodic_return=0.5668093711137772
# success =  tensor([False, False, False,  True, False, False, False, False],
#        device='cuda:0')
# env_step=259072, episodic_return=0.8141987174749374
# success =  tensor([False, False, False, False,  True, False, False, False],
#        device='cuda:0')
# env_step=259584, episodic_return=0.3246751129627228
# success =  tensor([False, False, False, False, False, False, False,  True],
#        device='cuda:0')
# env_step=264192, episodic_return=3.713002920150757
# success =  tensor([False, False, False, False, False, False,  True, False],
#        device='cuda:0')
# env_step=265216, episodic_return=0.9565363824367523
# success =  tensor([ True, False, False, False, False, False, False, False],
#        device='cuda:0')
# env_step=265728, episodic_return=0.47347450256347656
# success =  tensor([False, False, False, False,  True, False, False, False],
#        device='cuda:0')
# env_step=266240, episodic_return=0.4209012985229492
# success =  tensor([False,  True, False, False, False, False, False, False],
#        device='cuda:0')
# env_step=269312, episodic_return=2.4797247648239136
# success =  tensor([False, False, False, False, False, False,  True, False],
#        device='cuda:0')
# env_step=269824, episodic_return=0.5649418234825134
# success =  tensor([False, False, False,  True, False,  True, False, False],
#        device='cuda:0')
# env_step=270848, episodic_return=0.7603890001773834
# success =  tensor([False, False, False, False,  True, False, False, False],
#        device='cuda:0')
# env_step=272896, episodic_return=1.409168392419815
# success =  tensor([False, False, False, False, False, False, False,  True],
#        device='cuda:0')
# env_step=273408, episodic_return=0.359851598739624
# success =  tensor([False,  True, False, False, False, False, False, False],
#        device='cuda:0')
# env_step=274432, episodic_return=0.73268061876297
# success =  tensor([ True, False, False, False, False, False, False, False],
#        device='cuda:0')
# env_step=277504, episodic_return=2.44977068901062
# success =  tensor([False, False, False,  True,  True, False, False, False],
#        device='cuda:0')
# env_step=279040, episodic_return=1.068350076675415
# success =  tensor([False, False, False, False, False, False,  True, False],
#        device='cuda:0')
# env_step=281600, episodic_return=2.013044625520706
# success =  tensor([False, False, False, False, False, False, False,  True],
#        device='cuda:0')
# env_step=282112, episodic_return=0.3772464394569397
# success =  tensor([False, False, False, False, False, False, False, False],
#        device='cuda:0')
# env_step=282624, episodic_return=0.3769511580467224
# success =  tensor([False, False, False, False, False,  True, False, False],
#        device='cuda:0')
# env_step=283136, episodic_return=0.32601869106292725
# success =  tensor([ True, False, False, False, False, False, False, False],
#        device='cuda:0')
# env_step=285696, episodic_return=1.5011681914329529
# success =  tensor([False, False, False,  True, False, False, False, False],
#        device='cuda:0')
# env_step=286720, episodic_return=0.6155282855033875
# success =  tensor([False,  True, False, False, False, False, False, False],
#        device='cuda:0')
# env_step=288256, episodic_return=0.8791135847568512
# success =  tensor([False, False, False, False,  True, False, False, False],
#        device='cuda:0')
# env_step=292352, episodic_return=3.090098887681961
# success =  tensor([False, False, False, False, False, False,  True, False],
#        device='cuda:0')
# env_step=294400, episodic_return=1.8842093646526337
# success =  tensor([False,  True, False, False, False, False, False, False],
#        device='cuda:0')
# env_step=296960, episodic_return=2.286228746175766
# success =  tensor([ True, False, False, False, False, False, False, False],
#        device='cuda:0')
# env_step=297472, episodic_return=0.5000824928283691
# success =  tensor([False, False, False, False, False,  True, False, False],
#        device='cuda:0')
# env_step=297984, episodic_return=0.49722424149513245
# success =  tensor([False, False,  True, False,  True, False, False, False],
#        device='cuda:0')
# env_step=298496, episodic_return=0.36011803150177
# success =  tensor([False, False, False,  True, False, False, False, False],
#        device='cuda:0')
# env_step=300032, episodic_return=0.935672253370285
# success =  tensor([False, False, False, False, False, False, False,  True],
#        device='cuda:0')
# env_step=303104, episodic_return=2.367289811372757
# success =  tensor([False, False, False, False, False, False,  True, False],
#        device='cuda:0')
# env_step=303616, episodic_return=0.5364336967468262
# success =  tensor([False,  True,  True, False, False, False, False, False],
#        device='cuda:0')
# env_step=305664, episodic_return=1.5171485841274261
# success =  tensor([False, False, False, False, False, False, False,  True],
#        device='cuda:0')
# env_step=306176, episodic_return=0.3864503502845764
# success =  tensor([False, False, False,  True, False, False, False, False],
#        device='cuda:0')
# env_step=308224, episodic_return=1.4799870550632477
# success =  tensor([ True, False, False, False, False, False, False, False],
#        device='cuda:0')
# env_step=311296, episodic_return=2.8252545297145844
# success =  tensor([False, False, False, False, False, False, False,  True],
#        device='cuda:0')
# env_step=311808, episodic_return=0.538206934928894
# success =  tensor([False, False, False, False,  True, False, False, False],
#        device='cuda:0')
# env_step=312832, episodic_return=0.9758232235908508
# success =  tensor([False, False,  True,  True, False, False, False, False],
#        device='cuda:0')
# env_step=313856, episodic_return=0.7113153636455536
# success =  tensor([ True, False, False, False, False, False, False, False],
#        device='cuda:0')
# env_step=316416, episodic_return=1.840658277273178
# success =  tensor([False, False, False, False, False, False,  True, False],
#        device='cuda:0')
# env_step=316928, episodic_return=0.40465065836906433
# success =  tensor([False, False, False, False,  True, False, False, False],
#        device='cuda:0')
# env_step=318464, episodic_return=1.145969808101654
# success =  tensor([False, False,  True, False, False, False, False, False],
#        device='cuda:0')
# env_step=322048, episodic_return=3.093021512031555
# success =  tensor([False, False, False, False, False, False, False,  True],
#        device='cuda:0')
# env_step=323072, episodic_return=0.8780819177627563
# success =  tensor([False, False, False, False, False, False, False, False],
#        device='cuda:0')
# env_step=323584, episodic_return=0.4471589922904968
# success =  tensor([False, False, False, False, False, False,  True, False],
#        device='cuda:0')
# env_step=324096, episodic_return=0.41828453540802
# success =  tensor([ True, False, False, False, False, False, False, False],
#        device='cuda:0')
# env_step=324608, episodic_return=0.3637148141860962
# success =  tensor([False, False, False,  True, False, False, False, False],
#        device='cuda:0')
# env_step=326656, episodic_return=1.2357007563114166
# success =  tensor([False, False, False, False,  True, False, False, False],
#        device='cuda:0')
# env_step=329216, episodic_return=1.9297570884227753
# success =  tensor([False, False, False, False, False, False, False, False],
#        device='cuda:0')
# env_step=329728, episodic_return=0.4824778735637665
# success =  tensor([False, False, False, False, False, False, False,  True],
#        device='cuda:0')
# env_step=330752, episodic_return=0.9435586929321289
# success =  tensor([ True, False, False, False, False,  True, False, False],
#        device='cuda:0')
# env_step=331776, episodic_return=0.696773111820221
# success =  tensor([False, False, False, False, False, False,  True, False],
#        device='cuda:0')
# env_step=333312, episodic_return=0.9876446425914764
# success =  tensor([False, False, False, False,  True, False, False, False],
#        device='cuda:0')
# env_step=333824, episodic_return=0.4133322834968567
# success =  tensor([False, False,  True, False, False, False, False, False],
#        device='cuda:0')
# env_step=335360, episodic_return=1.0446573197841644
# success =  tensor([False, False, False,  True, False, False, False, False],
#        device='cuda:0')
# env_step=336384, episodic_return=0.7616329193115234
# success =  tensor([False, False, False, False, False, False, False,  True],
#        device='cuda:0')
# env_step=338432, episodic_return=1.5693735778331757
# success =  tensor([False,  True, False, False, False, False, False, False],
#        device='cuda:0')
# env_step=338944, episodic_return=0.4113451838493347
# success =  tensor([False, False, False, False, False,  True, False, False],
#        device='cuda:0')
# env_step=340480, episodic_return=1.0989623367786407
# success =  tensor([False, False, False, False, False, False,  True, False],
#        device='cuda:0')
# env_step=342528, episodic_return=1.4877258837223053
# success =  tensor([ True, False, False, False, False, False, False, False],
#        device='cuda:0')
# env_step=343552, episodic_return=0.8623988032341003
# success =  tensor([False, False, False, False,  True, False, False, False],
#        device='cuda:0')
# env_step=345088, episodic_return=1.3067449033260345
# success =  tensor([False, False, False,  True, False, False, False, False],
#        device='cuda:0')
# env_step=346112, episodic_return=0.8260405957698822
# success =  tensor([False, False, False, False, False,  True, False, False],
#        device='cuda:0')
# env_step=347136, episodic_return=0.8796859383583069
# success =  tensor([False,  True,  True, False, False, False,  True, False],
#        device='cuda:0')
# env_step=350208, episodic_return=1.9880219250917435
# success =  tensor([False, False, False,  True, False, False, False, False],
#        device='cuda:0')
# env_step=351744, episodic_return=1.4017647206783295
# success =  tensor([False, False, False, False, False, False, False,  True],
#        device='cuda:0')
# env_step=352256, episodic_return=0.4678277373313904
# success =  tensor([False, False, False, False,  True, False, False, False],
#        device='cuda:0')
# env_step=353280, episodic_return=0.8313650786876678
# success =  tensor([False,  True, False, False, False, False, False, False],
#        device='cuda:0')
# env_step=354304, episodic_return=0.8010676503181458
# success =  tensor([ True, False, False, False, False, False, False, False],
#        device='cuda:0')
# env_step=355328, episodic_return=0.7864314019680023
# success =  tensor([False, False,  True,  True, False, False, False, False],
#        device='cuda:0')
# env_step=355840, episodic_return=0.28253278136253357
# success =  tensor([False, False, False, False, False,  True, False, False],
#        device='cuda:0')
# env_step=357376, episodic_return=0.8229420930147171
# success =  tensor([False, False, False, False, False, False,  True, False],
#        device='cuda:0')
# env_step=359936, episodic_return=1.8861459791660309
# success =  tensor([False,  True, False, False,  True, False, False, False],
#        device='cuda:0')
# env_step=363520, episodic_return=2.7370622158050537
# success =  tensor([False, False, False, False, False, False, False,  True],
#        device='cuda:0')
# env_step=364032, episodic_return=0.47021228075027466
# success =  tensor([ True, False, False, False, False, False, False, False],
#        device='cuda:0')
# env_step=365056, episodic_return=0.8682075440883636
# success =  tensor([False, False, False,  True, False, False, False, False],
#        device='cuda:0')
# env_step=366080, episodic_return=0.7898802161216736
# success =  tensor([False, False, False, False,  True, False, False, False],
#        device='cuda:0')
# env_step=368128, episodic_return=1.4352557361125946
# success =  tensor([False, False, False, False, False,  True, False, False],
#        device='cuda:0')
# env_step=368640, episodic_return=0.35759252309799194
# success =  tensor([False, False, False, False, False, False,  True, False],
#        device='cuda:0')
# env_step=369152, episodic_return=0.3601289987564087
# success =  tensor([False,  True, False, False, False, False, False, False],
#        device='cuda:0')
# env_step=372736, episodic_return=2.407056152820587
# success =  tensor([False, False,  True, False, False, False, False, False],
#        device='cuda:0')
# env_step=374272, episodic_return=1.2761506140232086
# success =  tensor([False, False, False, False,  True, False, False, False],
#        device='cuda:0')
# env_step=376320, episodic_return=1.7858797311782837
# success =  tensor([ True, False, False, False, False,  True, False, False],
#        device='cuda:0')
# env_step=378368, episodic_return=1.7377559840679169
# success =  tensor([False, False,  True, False, False, False,  True,  True],
#        device='cuda:0')
# env_step=378880, episodic_return=0.29815179109573364
# success =  tensor([False, False, False,  True, False, False, False, False],
#        device='cuda:0')
# env_step=381952, episodic_return=1.5312442481517792
# success =  tensor([False, False, False, False,  True, False, False, False],
#        device='cuda:0')
# env_step=382976, episodic_return=0.7089318633079529
# success =  tensor([False,  True, False, False, False, False, False, False],
#        device='cuda:0')
# env_step=386560, episodic_return=2.9582630395889282
# success =  tensor([False, False, False, False, False, False, False,  True],
#        device='cuda:0')
# env_step=388096, episodic_return=1.446046531200409
# success =  tensor([False, False, False,  True, False, False, False, False],
#        device='cuda:0')
# env_step=390144, episodic_return=1.9567051231861115
# success =  tensor([False, False, False, False,  True,  True,  True, False],
#        device='cuda:0')
# env_step=391680, episodic_return=1.151394248008728
# success =  tensor([ True, False,  True, False, False, False, False, False],
#        device='cuda:0')
# env_step=393728, episodic_return=1.2441341280937195
# success =  tensor([False,  True, False,  True, False, False, False, False],
#        device='cuda:0')
# env_step=396288, episodic_return=1.6474831849336624
# success =  tensor([False, False, False, False, False, False, False,  True],
#        device='cuda:0')
# env_step=398336, episodic_return=1.8656300008296967
# success =  tensor([ True, False, False, False, False, False, False, False],
#        device='cuda:0')
# env_step=400384, episodic_return=1.8191241323947906
# success =  tensor([False,  True, False, False, False, False, False, False],
#        device='cuda:0')
# env_step=400896, episodic_return=0.5081959962844849
# success =  tensor([False, False,  True, False,  True, False, False, False],
#        device='cuda:0')
# env_step=402432, episodic_return=1.0920232236385345
# success =  tensor([False, False, False, False, False, False,  True, False],
#        device='cuda:0')
# env_step=403968, episodic_return=1.0657509863376617
# success =  tensor([False, False, False, False, False,  True, False, False],
#        device='cuda:0')
# env_step=407040, episodic_return=2.5654011368751526
# success =  tensor([ True, False,  True, False, False, False, False, False],
#        device='cuda:0')
#
#
#  Success rate: 0.9784615384615385
